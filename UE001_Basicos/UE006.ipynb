# %% [markdown]
# ![image.png](attachment:4e279049-b5d3-4575-b465-ac6b603141de.png)
#
# ![image.png](attachment:2a9eb940-0cbc-41c5-9e93-2049242b392e.png)
# # Clase Actor MiGeometria
#
# ### Recarga y compila en UE
# ![image.png](attachment:a53c6151-2db3-4a36-bc0b-495e663098ae.png)
#
# ### Compilación exitosa
# ![image.png](attachment:8c636325-bbd9-48a0-8a81-38564aa8ff8a.png)

# %% [markdown]
# # Mesh Generados
#
# ![image.png](attachment:0cfcd553-8e5c-4a53-9179-f72fc6ac8aa4.png)

# %% [markdown]
# # Analicemos lo que se tiene:
# - En el Viewport: Se ven claramente las tres figuras (esfera, cubo y cono) con la separación que programamos en el código.
# - En el panel de Details (Derecha): Se puede ver los componentes que creamos:
#     - CuboMesh, EsferaMesh y ConoMesh.
# - Como usamos UPROPERTY, ahora se puede cambiar el material o la malla directamente desde el editor sin tocar más código.
